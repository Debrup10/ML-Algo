# %% [markdown]
# <a href="https://colab.research.google.com/github/Debrup10/industryready/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_classification
X,y=make_classification(n_samples=1000,n_features=2,random_state=1,n_clusters_per_class=1, n_redundant=0)
print(X.shape,y.shape)
# Out:
# (1000, 2) (1000,)

# %%
X
# Out:
# array([[ 1.53682958, -1.39869399],
#        [ 1.36917601, -0.63734411],
#        [ 0.50231787, -0.45910529],
#        ...,
#        [ 1.82026677, -2.95716663],
#        [ 1.00499902,  0.93628981],
#        [ 1.46210987,  1.14497791]])

# %%
sns.scatterplot(x = pd.DataFrame(X)[0], y = pd.DataFrame(X)[1], hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
 from sklearn.svm import SVC

# %%
svc = SVC(kernel = 'linear')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Prediction
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       152
#            1       0.94      0.89      0.91       148
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300
#
# [[143   9]
#  [ 16 132]]

# %%
rbf = SVC(kernel = 'rbf')

# %%
rbf.fit(X_train, y_train)
# Out:
# SVC()
